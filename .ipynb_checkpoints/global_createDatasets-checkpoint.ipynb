# %%
import datetime
import numpy as np
import math
import os
import pandas as pd
import re
import seaborn as sns
import json
import statsmodels.api as sm 
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO    
from tqdm import tqdm 

    
from IPython.display import HTML
def View(df):
    css = """<style>
    table { border-collapse: collapse; border: 3px solid #eee; }
    table tr th:first-child { background-color: #eeeeee; color: #333; font-weight: bold }
    table thead th { background-color: #eee; color: #000; }
    tr, th, td { border: 1px solid #ccc; border-width: 1px 0 0 1px; border-collapse: collapse;
    padding: 3px; font-family: monospace; font-size: 10px }</style>
    """
    s  = '<script type="text/Javascript">'
    s += 'var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
    s += 'win.document.body.innerHTML = \'' + (df.to_html() + css).replace("\n",'\\') + '\';'
    s += '</script>'
    return(HTML(s+css))    

os.chdir(r'C:\Users\User\GitHub\WebET_Analysis')
print("Current Working directory " , os.getcwd())
# Out:
# Current Working directory  C:\Users\User\GitHub\WebET_Analysis

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Search for specific subjects

# %%
path = 'data_prolific'
subject_files = os.listdir(path)
for i in range(0, len(subject_files)):
    thisSubject_txt = open(path + "/" + subject_files[i]).read()
    if thisSubject_txt.find('Unnamed') > (-1):
        print(subject_files[i])

# %% [markdown]
# ## Read CSV from String

# %%
def cleanhtml(raw_html):
    # https://stackoverflow.com/questions/9662346/python-code-to-remove-html-tags-from-a-string
    cleanr = re.compile('<.*?>')
    cleanText = re.sub(cleanr, '', raw_html)
    return cleanText

def cleanETText(text):
    textWithinBrackets = re.findall(re.compile('\[.*?\]'), text)
    output = text
    for i in range(0,len(textWithinBrackets)):
        old = textWithinBrackets[i]
        new = re.sub(",", "$", old)
        output = output.replace(old, new)
    return output

def cleanSurveyText(text):
    output = text
    textWithinBrackets = re.findall(re.compile('\{.*?\}'), text)
    for i in range(0,len(textWithinBrackets)):
        old = textWithinBrackets[i]
        new = old.replace(',', '§')
        output = output.replace(old, new)
    return output

def compileData(path):
    subject_files = os.listdir(path)
    all_subjects = []
    for i in tqdm(range(0, len(subject_files))):
        csv_thisSubject = open(path + "/" + subject_files[i]).read()
        csv_thisSubject = cleanhtml(csv_thisSubject)
        csv_thisSubject = cleanETText(csv_thisSubject)
        csv_thisSubject = cleanSurveyText(csv_thisSubject)
        df_thisSubject = pd.read_csv(StringIO(csv_thisSubject))
        if len(df_thisSubject) > 0: 
            all_subjects.append(df_thisSubject)
    output = pd.concat(all_subjects).reset_index(drop=True)
    return output

data_raw = compileData("data_prolific")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 467/467 [01:10<00:00,  6.60it/s]

# %% [markdown]
# ## survey data (to merge with data_subject)

# %%
def cleanOptionalNote(text):
    optionalNoteText = re.findall(re.compile('optionalNote":.*?\}'), text)
    if len(optionalNoteText) < 1:
        output = text
    else:
        old = optionalNoteText[0]
        new = old.replace('§', ' ') \
            .replace(':', ' ') \
            .replace('(', ' ') \
            .replace(')', ' ') \
            .replace('optionalNote" ', 'optionalNote":')
        
        output = text.replace(old, new)
    return output


def surveyStringToFrame(subject, string):
    string = cleanOptionalNote(string)
    string = re.sub("""{""", '', string)
    string = re.sub("""}""", '', string)
    string = re.sub('"', '', string)
    string = re.sub('§', '$', string)
    output = pd.read_csv(StringIO(string),
                         sep=":",
                         lineterminator="$",
                         header=None,
                         index_col=0
                         ).transpose()
    return output


def surveyData_thisSubject(data):
    
    subject = data['run_id'].unique()[0]
    output = []
    for i in range(0, len(data)):
        output.append(
            surveyStringToFrame(subject,
                                data.loc[i, 'responses'])
        )

    output = pd.concat(output, axis=1)
    output['run_id'] = subject

    return output


def surveyData(data):
    surveyData = pd.DataFrame(columns=[
            'prolificID', 'age', 'gender', 'ethnic', 'sight', 
            'glasses', 'degree', 'eyeshadow', 'masquara', 'eyeliner', 
            'browliner', 'vertPosition', 'triedChin', 'keptHead', 
            'optionalNote', 'run_id'])

    for subject in tqdm(data['run_id'].unique()):
        
        df_thisSubject = data.loc[
            (data['run_id']==subject) & 
            (pd.notna(data["responses"])) &
            (data["responses"] != '"'), 
            ['run_id', 'responses']
        ] \
            .reset_index()
        
        if len(df_thisSubject)>0:
        
            surveyData = \
                surveyData.append(
                    surveyData_thisSubject(
                        df_thisSubject
                    )
                )
    
    return(surveyData)
    
surveyData = surveyData(data_raw)
surveyData
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 316/316 [00:11<00:00, 28.25it/s]
#                   prolificID   age  gender     ethnic         sight  \
# 1   5fccc8ac636416a4288a9f3d  1995    male  caucasian       glasses
# 1   600063f2943eab0acc812ed8  2001    male  caucasian  perfectSight
# 1   5d485e8415055400194b707f   NaN     NaN        NaN           NaN
# 1   55b237e6fdf99b19ea79d2f7   NaN     NaN        NaN           NaN
# 1   5c5684ef9d244c0001b29f1e  1991    male      asian       glasses
# ..                       ...   ...     ...        ...           ...
# 1   5ecfc227f036c902457fc44c  1998  female      black  perfectSight
# 1   5eb9940830ab6c098bd1943d  1997    male  caucasian  perfectSight
# 1   5f68fe5be5cc370c0a0911de  1988  female  caucasian  perfectSight
# 1   5f779405dacc842fc44bc767  1996    male  caucasian       glasses
# 1    55b237e6fdf99b19ea79d2f   NaN     NaN        NaN           NaN
#
#          glasses                              degree eyeshadow masquara  \
# 1     shortSight                         High School        no       no
# 1   noCorrection  College / Undergraduate / Bachelor        no       no
# 1            NaN                                 NaN       NaN      NaN
# 1            NaN                                 NaN       NaN      NaN
# 1     shortSight  College / Undergraduate / Bachelor        no       no
# ..           ...                                 ...       ...      ...
# 1   noCorrection             Graduate / PhD / Master        no       no
# 1   noCorrection  College / Undergraduate / Bachelor        no       no
# 1   noCorrection                                 NaN        no       no
# 1      longSight                                   2        no       no
# 1            NaN                                 NaN       NaN      NaN
#
#    eyeliner browliner vertPosition triedChin keptHead optionalNote run_id
# 1        no        no            a       yes      yes          NaN      1
# 1        no        no            a       NaN      NaN          NaN    103
# 1       NaN       NaN          NaN       NaN      NaN          NaN    106
# 1       NaN       NaN          NaN       NaN      NaN          NaN    108
# 1        no        no            a       yes      yes          NaN     11
# ..      ...       ...          ...       ...      ...          ...    ...
# 1        no        no            a       yes      yes          NaN     94
# 1        no        no            a       yes      yes          NaN     96
# 1        no        no            b       yes      yes          NaN     97
# 1        no        no            b       yes      yes          NaN     98
# 1       NaN       NaN          NaN       NaN      NaN          NaN     99
#
# [302 rows x 16 columns]

# %% [markdown]
# ### Cleaning

# %%
surveyData['degree'] = surveyData['degree'].replace(
    ['-3.0', '0', '1.25', '1.5', '2', '4.25'], np.nan)


surveyData['degree'] = surveyData['degree'].replace({
    'Middle School': 'middle',
    'High School': 'high',
    'high school': 'high',
    'Associate ': 'high',
    'masters degree': 'grad',
    'College / Undergraduate / Bachelor': 'college',
    'Bachelor': 'college',
    'Grad': 'grad',
    'Graduate / PhD / Master': 'grad',
    'masters degree': 'grad'
})
surveyData['degree'].unique()
# Out:
# array(['high', 'college', nan, 'grad', 'Associates Degree', 'highSchool',
#        'graduate', 'middleSchool', 'middle'], dtype=object)

# %%
def convertToNumeric(data, columns):
    data[columns] = data[columns].apply(pd.to_numeric, errors='coerce')
    return data

surveyData = convertToNumeric(surveyData, ['age'])

# %% [markdown]
# ### Optional Notes

# %%
pd.set_option('max_colwidth', 200)

data_optionalNotes = surveyData.loc[
        pd.notna(surveyData['optionalNote']), 
        ['run_id', 'optionalNote']
    ]
data_optionalNotes
# Out:
#   run_id  \
# 1    208
# 1    227
# 1    238
# 1    256
# 1    266
# 1    270
# 1    347
# 1    361
# 1    380
# 1    429
# 1     66
# 1      7
# 1     85
# 1     93
#
#                                                                                                                                                                                               optionalNote
# 1                                                                                                                                                                                     no further comments.
# 1                                                                                               So much white text on a black background made my eyes tired so I'm sorry if that interfered with anything!
# 1  It was hard! Sorry my cat came along. Also  I am being tested for multiple sclerosis right now  but it has not been doing anything to my vision. So hopefully you can still use mine - I haven't bee...
# 1                      Of course you can hear my family suddenly and randomly ask me questions in the background but I swear to you I kept my eyes on the center of the monitor and I clicked everything.
# 1                                                                                                                                                                                                       Na
# 1                                                                                                                                I think I managed to stay pretty still  but my heart raced after awhile.
# 1                                                        I noticed my head had moved from the first picture to the last picture while my head was resting on my hand even though I had tried to hold still
# 1
# 1                                                     i am so sorry if you can hear my wife in this and for me getting up quite a bit. i hope i'm still eligible but i'm just being honest  tried my best!
# 1                                                                                                                                                                I had allergies so my eyes were watering
# 1                                                                                                                                                                                             good survey.
# 1                                                                                                                                                     I believe I stayed still  but maybe a moved a little
# 1                                                                                                                                                                              This study took a long time
# 1                                                                                                                                                                                 THE SURVEY WAS ENJOYABLE

# %%
pd.set_option('max_colwidth', 40)

# %%
for subject in data_optionalNotes['run_id'].unique():
    print(f'run_id: {subject}')
    print(surveyData.loc[
        surveyData['run_id']==subject, 
        'optionalNote'].values[0])
    print('\n')
# Out:
# run_id: 208
# no further comments.
#
#
# run_id: 227
# So much white text on a black background made my eyes tired so I'm sorry if that interfered with anything!
#
#
# run_id: 238
# It was hard! Sorry my cat came along. Also  I am being tested for multiple sclerosis right now  but it has not been doing anything to my vision. So hopefully you can still use mine - I haven't been diagnosed with anything yet.
#
#
# run_id: 256
# Of course you can hear my family suddenly and randomly ask me questions in the background but I swear to you I kept my eyes on the center of the monitor and I clicked everything.
#
#
# run_id: 266
# Na
#
#
# run_id: 270
# I think I managed to stay pretty still  but my heart raced after awhile.
#
#
# run_id: 347
# I noticed my head had moved from the first picture to the last picture while my head was resting on my hand even though I had tried to hold still
#
#
# run_id: 361
#
#
#
# run_id: 380
# i am so sorry if you can hear my wife in this and for me getting up quite a bit. i hope i'm still eligible but i'm just being honest  tried my best!
#
#
# run_id: 429
# I had allergies so my eyes were watering
#
#
# run_id: 66
# good survey.
#
#
# run_id: 7
# I believe I stayed still  but maybe a moved a little
#
#
# run_id: 85
# This study took a long time
#
#
# run_id: 93
# THE SURVEY WAS ENJOYABLE

# %% [markdown]
# ## Add to data_raw

# %%
if 'prolificID' in data_raw.columns:
    data_raw = data_raw.drop(columns='prolificID')
    
data_raw = data_raw \
    .merge(
        surveyData.loc[:, ['run_id', 'prolificID']],
        on='run_id',
        how='left'
)

# %% [markdown]
# ## Trial type new

# %% [markdown]
# Most of these subjects reloaded when the eye-tracking initialized as well as during the first calibration

# %%
data_raw['trial_type_new'] = 0
    
data_raw.loc[
    (data_raw['run_id']<144) & 
    (data_raw['chinFirst']==0), 
    'trial_type_new'
] = pd.cut(
    data_raw.loc[
        (data_raw['run_id']<144) & 
        (data_raw['chinFirst']==0), 
        'trial_index'], 
    np.array([
        0,
        1.5, # start_page
        2.5, # prolific_id
        4.5, # pre_et_init
        5.5, # et_init
        11, # et_adjustment
        17.5, # calibration_1_briefing
        18.5, # first_cal
        97, # calibration_1
        134, # fixation_1
        221, # calibration_2
        259, # fixation_2
        514, # choice
        520 # end
    ]),
    labels=np.array([
        'start_page',
        'prolific_id',
        'pre_et_init',
        'et_init',
        'et_adjustment',
        'calibration_1_briefing',
        'first_cal', 
        'calibration_1',
        'fixation_1',
        'calibration_2',
        'fixation_2',
        'choice',
        'end'
    ]),
    include_lowest=True, 
)

data_raw.loc[
    (data_raw['run_id']<144) & 
    (data_raw['chinFirst']==1), 
    'trial_type_new'
] = pd.cut(
    data_raw.loc[
        (data_raw['run_id']<144) & 
        (data_raw['chinFirst']==1), 
        'trial_index'], 
    np.array([
        0, # 
        1.5, # start_page
        2.5, # prolific_id
        4.5, # pre_et_init
        5.5, # et_init
        11, # et_adjustment
        17.5, # calibration_1_briefing
        18.5, # first_cal
        97, # calibration_1
        134, # fixation_1
        387, # choice
        473, # calibration_2
        513, # fixation_2
        520 # end
    ]),
    labels=np.array([
        'start_page',
        'prolific_id',
        'pre_et_init',
        'et_init',
        'et_adjustment',
        'calibration_1_briefing',
        'first_cal', 
        'calibration_1',
        'fixation_1',
        'choice',        
        'calibration_2',
        'fixation_2',
        'end'
    ]),
    include_lowest=True, 
)

data_raw.loc[
    (data_raw['run_id']<144) & 
    (data_raw['chinFirst']==0), 
    ['trial_index', 'trial_type_new', 'trial_type', 'stimulus', 'task_nr']
].iloc[0:40]

pd.set_option('display.max_rows', 500)
data_raw \
    .groupby(['trial_index'])['trial_type'].unique() \
    .iloc[0:100]
# Out:
# trial_index
# 0      [html-keyboard-response]
# 1        [html-button-response]
# 2            [survey-html-form]
# 3        [html-button-response]
# 4        [html-button-response]
# 5            [eyetracking-init]
# 6      [html-keyboard-response]
# 7        [html-button-response]
# 8        [html-button-response]
# 9      [html-keyboard-response]
# 10                 [fullscreen]
# 11     [html-keyboard-response]
# 12     [html-keyboard-response]
# 13     [html-keyboard-response]
# 14     [html-keyboard-response]
# 15     [html-keyboard-response]
# 16     [html-keyboard-response]
# 17     [html-keyboard-response]
# 18    [eyetracking-calibration]
# 19     [html-keyboard-response]
# 20    [eyetracking-calibration]
# 21     [html-keyboard-response]
# 22    [eyetracking-calibration]
# 23     [html-keyboard-response]
# 24    [eyetracking-calibration]
# 25     [html-keyboard-response]
# 26    [eyetracking-calibration]
# 27     [html-keyboard-response]
# 28    [eyetracking-calibration]
# 29     [html-keyboard-response]
# 30    [eyetracking-calibration]
# 31     [html-keyboard-response]
# 32    [eyetracking-calibration]
# 33     [html-keyboard-response]
# 34    [eyetracking-calibration]
# 35     [html-keyboard-response]
# 36    [eyetracking-calibration]
# 37     [html-keyboard-response]
# 38    [eyetracking-calibration]
# 39     [html-keyboard-response]
# 40    [eyetracking-calibration]
# 41     [html-keyboard-response]
# 42    [eyetracking-calibration]
# 43     [html-keyboard-response]
# 44    [eyetracking-calibration]
# 45     [html-keyboard-response]
# 46    [eyetracking-calibration]
# 47     [html-keyboard-response]
# 48    [eyetracking-calibration]
# 49     [html-keyboard-response]
# 50    [eyetracking-calibration]
# 51     [html-keyboard-response]
# 52    [eyetracking-calibration]
# 53     [html-keyboard-response]
# 54    [eyetracking-calibration]
# 55     [html-keyboard-response]
# 56    [eyetracking-calibration]
# 57     [html-keyboard-response]
# 58    [eyetracking-calibration]
# 59     [html-keyboard-response]
# 60    [eyetracking-calibration]
# 61     [html-keyboard-response]
# 62    [eyetracking-calibration]
# 63     [html-keyboard-response]
# 64    [eyetracking-calibration]
# 65     [html-keyboard-response]
# 66    [eyetracking-calibration]
# 67     [html-keyboard-response]
# 68    [eyetracking-calibration]
# 69     [html-keyboard-response]
# 70    [eyetracking-calibration]
# 71     [html-keyboard-response]
# 72    [eyetracking-calibration]
# 73     [html-keyboard-response]
# 74    [eyetracking-calibration]
# 75     [html-keyboard-response]
# 76    [eyetracking-calibration]
# 77     [html-keyboard-response]
# 78    [eyetracking-calibration]
# 79     [html-keyboard-response]
# 80    [eyetracking-calibration]
# 81     [html-keyboard-response]
# 82    [eyetracking-calibration]
# 83     [html-keyboard-response]
# 84    [eyetracking-calibration]
# 85     [html-keyboard-response]
# 86    [eyetracking-calibration]
# 87     [html-keyboard-response]
# 88    [eyetracking-calibration]
# 89     [html-keyboard-response]
# 90    [eyetracking-calibration]
# 91     [html-keyboard-response]
# 92    [eyetracking-calibration]
# 93     [html-keyboard-response]
# 94    [eyetracking-calibration]
# 95     [html-keyboard-response]
# 96     [html-keyboard-response]
# 97     [html-keyboard-response]
# 98     [html-keyboard-response]
# 99     [html-keyboard-response]
# Name: trial_type, dtype: object

# %%
pd.set_option('display.max_rows', 10)

# %%
data_raw.loc[
    (data_raw['run_id']>143) & 
    (data_raw['chinFirst']==0), 
    'trial_type_new'
] = pd.cut(
    data_raw.loc[
        (data_raw['run_id']>143) & 
        (data_raw['chinFirst']==0), 
        'trial_index'], 
    np.array([
        0,
        1.5, # start_page
        2.5, # prolific_id
        4.5, # pre_et_init
        5.5, # et_init
        11, # et_adjustment
        17.5, # calibration_1_briefing
        97, # calibration_1
        143, # fixation_1
        231, # calibration_2
        277, # fixation_2
        532, # choice
        540 # end
    ]),
    labels=np.array([
        'start_page',
        'prolific_id',
        'pre_et_init',
        'et_init',
        'et_adjustment',
        'calibration_1_briefing',
        'calibration_1',
        'fixation_1',
        'calibration_2',
        'fixation_2',
        'choice',
        'end'
    ]),
    include_lowest=True, 
)

data_raw.loc[
    (data_raw['run_id']>143) & 
    (data_raw['chinFirst']==1), 
    'trial_type_new'
] = pd.cut(
    data_raw.loc[
        (data_raw['run_id']>143) & 
        (data_raw['chinFirst']==1), 
        'trial_index'], 
    np.array([
        0, # 
        1.5, # start_page
        2.5, # prolific_id
        4.5, # pre_et_init
        5.5, # et_init
        11, # et_adjustment
        17.5, # calibration_1_briefing
        97, # calibration_1
        143, # fixation_1
        397, # choice
        483, # calibration_2
        532, # fixation_2
        540 # end
    ]),
    labels=np.array([
        'start_page',
        'prolific_id',
        'pre_et_init',
        'et_init',
        'et_adjustment',
        'calibration_1_briefing',
        'calibration_1',
        'fixation_1',
        'choice',        
        'calibration_2',
        'fixation_2',
        'end'
    ]),
    include_lowest=True, 
)

data_raw.loc[
    (data_raw['run_id']>143) & 
    (data_raw['chinFirst']==1), 
    ['trial_index', 'trial_type_new', 'trial_type', 'stimulus', 'task_nr']
].iloc[530:540]
# Out:
#       trial_index trial_type_new              trial_type  \
# 5258          530     fixation_2  html-keyboard-response
# 5259          531     fixation_2  html-keyboard-response
# 5260          532     fixation_2              fullscreen
# 5261          533            end  html-keyboard-response
# 5262          534            end        survey-html-form
# 5263          535            end        survey-html-form
# 5264          536            end        survey-html-form
# 5265          537            end        survey-html-form
# 5813            0     start_page  html-keyboard-response
# 5814            1     start_page    html-button-response
#
#                                      stimulus task_nr
# 5258                                        "       "
# 5259                                        "       "
# 5260                                        "       "
# 5261  You completed the study to 90% Press...       "
# 5262                                        "       "
# 5263                                        "       "
# 5264                                        "       "
# 5265                                        "       "
# 5813                                        "     NaN
# 5814  Welcome, dear participant! Thank you...     NaN

# %%
order_trial_types = pd.DataFrame(
    {'trial_type_new': [
                'start_page',
                'prolific_id',
                'pre_et_init',
                'et_init',
                'et_adjustment',
                'calibration_1_briefing',
                'calibration_1',
                'fixation_1',     
                'calibration_2',
                'fixation_2',
                'choice',   
                'end'
            ],
     'trial_type_nr': np.arange(12)
    }
)

if 'trial_type_nr' in data_raw.columns: 
    data_raw = data_raw.drop(columns='trial_type_nr')
    
data_raw = data_raw \
    .merge(order_trial_types, on='trial_type_new', how='left')

# %% [markdown]
# ## Dropouts (on run level)

# %%
def add_next_trial(data):
    full_trials_no_chin = data_raw.loc[
        data_raw['run_id']==421, 
        ['trial_index', 'trial_type', 'trial_type_new']
    ].reset_index(drop=True)

    next_trials_no_chin = full_trials_no_chin
    next_trials_no_chin['trial_index'] -= 1

    full_trials_chin = data_raw.loc[
        data_raw['run_id']==270, 
        ['trial_index', 'trial_type', 'trial_type_new']
    ].reset_index(drop=True)

    next_trials_chin = full_trials_chin
    next_trials_chin['trial_index'] -= 1
    
    data = data.copy()
    data['next_trial_type']=0
    data['next_trial_type_new']=0

    for i in data.index:
        this_trial = data.loc[i, 'trial_index']

        if data.loc[i, 'trial_type_new'] != 'end':
            next_trials = next_trials_chin if data.loc[i, 'chinFirst']>0 else next_trials_no_chin
            
            next_trial = next_trials.loc[
                next_trials['trial_index']==this_trial,
                'trial_type'
            ].values[0]
            data.loc[i, 'next_trial_type']=next_trial

            next_trial = next_trials.loc[
                next_trials['trial_index']==this_trial,
                'trial_type_new'
            ].values[0]
            data.loc[i, 'next_trial_type_new']=next_trial
            
        else:
            data.loc[i, 'next_trial_type']='end'
            data.loc[i, 'next_trial_type_new']='end'
            
    return data

# %% [markdown]
# Most runs drop out at the beginning (8.8% chinFirst +7.2% no chinFirst), in detail, during the initialization of Webgazer (4.4%+3.2%), during the calibration instruction (0.6%+2.5%) and the calibration itself (1.2+0.3%). Moreover, some dropouts during the tasks (0.6+1.8%).

# %%
def dropout(data):
    grouped_trial_type_new = data \
        .loc[: , ['run_id', 'chinFirst', 'trial_index', 'trial_type_new']] \
        .drop_duplicates()

    last_trial_for_each_subject = data \
        .groupby(['run_id'])['trial_index'].max() \
        .reset_index() \
        .merge(grouped_trial_type_new, on=['run_id', 'trial_index'], how='left')
    
    last_trial_for_each_subject = add_next_trial(last_trial_for_each_subject)
    
    dropout_by_type = last_trial_for_each_subject \
        .groupby(['trial_type_new', 'next_trial_type']).count() \
        .reset_index() \
        .rename(columns={'run_id': 'n_run_id'}) \
        .loc[
            :, 
            [
               'trial_type_new', 'next_trial_type', 'next_trial_type_new', 'n_run_id', 
            ]
        ] \
        .sort_values(by='n_run_id')
    
    
    
    
    dropout_by_type['perc'] = round(
        100 * dropout_by_type['n_run_id'] / len(data_raw['run_id'].unique()), 
        1
    )
    
    summary = pd.DataFrame([
        [
            'beginning', 'beginning', 'beginning', 
            sum(dropout_by_type.loc[
                dropout_by_type['next_trial_type'].isin([
                    'pre_et_init',
                    'et_init', 
                    'et_adjustment',
                    'calibration_1_briefing',
                    'calibration_1',
                ]),
                'n_run_id']),
            sum(dropout_by_type.loc[
                dropout_by_type['next_trial_type'].isin([
                    'pre_et_init',
                    'et_init', 
                    'et_adjustment',
                    'calibration_1_briefing',
                    'calibration_1',
                ]),
                'perc'])
        ], 
                [
            'et_tasks', 'et_tasks', 'et_tasks', 
            sum(dropout_by_type.loc[
                dropout_by_type['next_trial_type'].isin([
                    'fixation_1',
                    'fixation_2',
                    'calibration_2',
                    'choice',
                ]),
                'n_run_id']),
            sum(dropout_by_type.loc[
                dropout_by_type['next_trial_type'].isin([
                    'fixation_1',
                    'fixation_2',
                    'calibration_2',
                    'choice',
                ]),
                'perc'])
        ],
        [
            'total', 'total', 'total', 
            sum(dropout_by_type['n_run_id']),
            sum(dropout_by_type['perc'])
        ]
    
    ], columns=dropout_by_type.columns)
    
    dropout_by_type = dropout_by_type.append(summary)

    return dropout_by_type

print('chinFirst==0')
print(dropout(data_raw.loc[data_raw['chinFirst']==0, :]))
print('\n')
print('chinFirst==1')
print(dropout(data_raw.loc[data_raw['chinFirst']==1, :]))
# Out:
# chinFirst==0
#             trial_type_new          next_trial_type next_trial_type_new  \
# 0            calibration_1  eyetracking-calibration                   1
# 3            calibration_2  eyetracking-calibration                   1
# 4                   choice   eyetracking-fix-object                   1
# 6            et_adjustment     html-button-response                   1
# 7            et_adjustment   html-keyboard-response                   1
# 2   calibration_1_briefing   html-keyboard-response                   2
# 9              prolific_id     html-button-response                   4
# 1            calibration_1   html-keyboard-response                   5
# 10              start_page     html-button-response                   5
# 8              pre_et_init         eyetracking-init                  14
# 5                      end                      end                 124
# 0                beginning                beginning           beginning
# 1                 et_tasks                 et_tasks            et_tasks
# 2                    total                    total               total
#
#     n_run_id  perc
# 0          1   0.3
# 3          1   0.3
# 4          1   0.3
# 6          1   0.3
# 7          1   0.3
# 2          2   0.6
# 9          4   1.3
# 1          5   1.6
# 10         5   1.6
# 8         14   4.4
# 5        124  39.2
# 0          0   0.0
# 1          0   0.0
# 2        159  50.2
#
#
# chinFirst==1
#             trial_type_new          next_trial_type next_trial_type_new  \
# 0            calibration_1  eyetracking-calibration                   1
# 2            calibration_2  eyetracking-calibration                   1
# 3            calibration_2   html-keyboard-response                   1
# 4                   choice   eyetracking-fix-object                   1
# 8               fixation_2   html-keyboard-response                   1
# 5                   choice   html-keyboard-response                   2
# 7            et_adjustment     html-button-response                   2
# 10             prolific_id     html-button-response                   2
# 1   calibration_1_briefing   html-keyboard-response                   8
# 11              start_page     html-button-response                   9
# 9              pre_et_init         eyetracking-init                  10
# 6                      end                      end                 119
# 0                beginning                beginning           beginning
# 1                 et_tasks                 et_tasks            et_tasks
# 2                    total                    total               total
#
#     n_run_id  perc
# 0          1   0.3
# 2          1   0.3
# 3          1   0.3
# 4          1   0.3
# 8          1   0.3
# 5          2   0.6
# 7          2   0.6
# 10         2   0.6
# 1          8   2.5
# 11         9   2.8
# 9         10   3.2
# 6        119  37.7
# 0          0   0.0
# 1          0   0.0
# 2        157  49.5

# %% [markdown]
# ### Inspect calibration

# %% [markdown]
# The last trial during calibration varies. There no one 'first calibration' or similar, when the subjects drop out

# %%
grouped_trial_type_new = data \
    .loc[: , ['run_id', 'chinFirst', 'trial_index', 'trial_type_new']] \
    .drop_duplicates()

last_trial_for_each_subject = data \
    .groupby(['run_id'])['trial_index'].max() \
    .reset_index() \
    .merge(grouped_trial_type_new, on=['run_id', 'trial_index'], how='left')

last_trial_for_each_subject = add_next_trial(last_trial_for_each_subject)
last_trial_for_each_subject.loc[
    last_trial_for_each_subject['trial_type_new']=='calibration_1'
]
# Out:
#     run_id  trial_index  chinFirst trial_type_new          next_trial_type  \
# 68     141           19          0  calibration_1  eyetracking-calibration
# 127    221           19          1  calibration_1  eyetracking-calibration
# 135    229           90          0  calibration_1   html-keyboard-response
# 191    300           28          0  calibration_1   html-keyboard-response
# 212    332           26          0  calibration_1   html-keyboard-response
# 245    374           18          0  calibration_1   html-keyboard-response
# 299    443           70          0  calibration_1   html-keyboard-response
#
#     next_trial_type_new
# 68        calibration_1
# 127       calibration_1
# 135       calibration_1
# 191       calibration_1
# 212       calibration_1
# 245       calibration_1
# 299       calibration_1

# %% [markdown]
# ## Duplicate Prolific ID's - Multiple participations

# %%
duplicates = data_raw.loc[
    pd.notna(data_raw['prolificID']), 
    ['prolificID', 'trial_index']
].duplicated()

duplicate_subjects = data_raw.loc[
    pd.notna(data_raw['prolificID']) & 
    duplicates, 
    'prolificID'
].unique()

if len(duplicateSubjects) > 0:
    print(f'! Attention: Duplicate prolific IDs ! \n')
    print(f' - Number of subjects who had to try multiple times: {len(duplicate_subjects)}')
    print(f' - Sum of duplicate entries in data_raw (prolificID & trial_index): {sum(duplicates)}')

else:
    print('Success: No duplicate subjects found')
# Out:
# ! Attention: Duplicate prolific IDs !
#
#  - Number of subjects who had to try multiple times: 19
#  - Sum of duplicate entries in data_raw (prolificID & trial_index): 214

# %% [markdown]
# Most subjects, who had to redo, previously dropped out during calibration briefing (n=7) and the initialization (n=11) multiple times

# %%
runs_max_trial = data_raw.loc[data_raw['prolificID'].isin(duplicate_subjects), :] \
    .groupby(['prolificID', 'run_id'], as_index=False)['trial_index'].max() \
    .merge(
        data_raw.loc[
            :, 
            ['run_id', 'chinFirst', 'trial_index', 'trial_type', 'trial_type_nr', 'trial_type_new']
        ], 
        on=['run_id', 'trial_index'], 
        how='left')
runs_max_trial = runs_max_trial \
    .loc[runs_max_trial['trial_type_new']!='end', :]

runs_max_trial= add_next_trial(runs_max_trial)

runs_max_trial.head(10)
# Out:
#                    prolificID run_id  trial_index  chinFirst  \
# 0    56b7a271e77ebe000bbeff49    124            4          1
# 1    56b7a271e77ebe000bbeff49    125           15          1
# 2    5c5219d7823a35000128d460    351          285          1
# 3    5c5219d7823a35000128d460    353            8          0
# 4   5c95970cd676900016e1a940     168           14          1
# 5   5c95970cd676900016e1a940     178           14          1
# 6   5c95970cd676900016e1a940     181           14          1
# 8    5cbe04b4f429ff00159de30e    388           14          0
# 10   5d754a0ae8351c0001f3ffc8    147            4          0
# 11   5d754a0ae8351c0001f3ffc8    148            4          0
#
#                 trial_type  trial_type_nr          trial_type_new  \
# 0     html-button-response            2.0             pre_et_init
# 1   html-keyboard-response            5.0  calibration_1_briefing
# 2   html-keyboard-response           10.0                  choice
# 3     html-button-response            4.0           et_adjustment
# 4   html-keyboard-response            5.0  calibration_1_briefing
# 5   html-keyboard-response            5.0  calibration_1_briefing
# 6   html-keyboard-response            5.0  calibration_1_briefing
# 8   html-keyboard-response            5.0  calibration_1_briefing
# 10    html-button-response            2.0             pre_et_init
# 11    html-button-response            2.0             pre_et_init
#
#            next_trial_type
# 0                  et_init
# 1   calibration_1_briefing
# 2                   choice
# 3            et_adjustment
# 4   calibration_1_briefing
# 5   calibration_1_briefing
# 6   calibration_1_briefing
# 8   calibration_1_briefing
# 10                 et_init
# 11                 et_init

# %%
runs_max_trial \
    .groupby(['next_trial_type']).nunique()['prolificID'] \
    .reset_index() \
    .sort_values(by='prolificID')
# Out:
#           next_trial_type  prolificID
# 2                  choice           1
# 5             pre_et_init           1
# 0           calibration_1           2
# 3           et_adjustment           2
# 1  calibration_1_briefing           7
# 4                 et_init          11

# %% [markdown]
# ## Binary data

# %%
data_raw['chinFirst'] = data_raw['chinFirst'].replace({'no': 0, 'yes': 1})

# %% [markdown]
# ## Numerics

# %%
columns = [
            'eyeshadow', 
            'masquara',
            'eyeliner',
            'browliner',
            'triedChin', 
            'keptHead'
        ]

for col in columns:
    surveyData[col] = surveyData[col].replace({'no': 0, 'yes': 1})

# %% [markdown]
# # data_trial

# %%
data_trial = data_raw.loc[
    :,
    [
        'run_id', 'subject', 'chinFirst', 
        'trial_index',
        'trial_type', 'task_nr', 
        'rt', 'stimulus', 'key_press', 
        'time_elapsed', 'trial_duration', 'recorded_at',
        'window_width', 'window_height', 'success', 

        'chin', 'x_pos', 'y_pos', 
        
        'choiceTask_amountLeftFirst', 
        'option_topLeft', 'option_bottomLeft',
        'option_topRight', 'option_bottomRight', 
        'chosenAmount', 'chosenDelay',
    ]
]

# %% [markdown]
# ### Numerics

# %%
data_trial = convertToNumeric(data_trial, 
    [
        'run_id', 'subject', 'chinFirst', 'chin', 'task_nr', 'trial_index', # Int
        'key_press', 
        'x_pos', 'y_pos', 'time_elapsed', 'trial_duration',
        'rt',
        'window_width', 'window_height'
    ]
)

# %% [markdown]
# # data_et

# %% [markdown]
# ## Compile

# %%
def reformatYang(text):
    text = text.replace('$', ',')
    text = text.replace("relative-x", "x")
    text = text.replace("relative-y", 'y')
    text = text.replace('elapse-time', 't')
    text = (text[11:len(text)-1])
    return(text)

#for subject in data_yang['run_id'].unique():
#    for i in data_raw.loc[
#        (data_raw['run_id']==subject) & 
#        (pd.notna(data_raw['et_data'])) &
#        ~(data_raw['et_data'].isin(['"', 'nan'])), 
#       :].index:
#       print('Reformat index: ' + str(i))
#       data_raw.loc[i, 'et_data'] = reformatYang(data_raw.loc[i, 'et_data'])

# %%
len(data_raw.loc[
        (pd.notna(data_raw['et_data'])) & 
        ~(data_raw['et_data'].isin(['"', '[]', 'nan'])), 
        'et_data'].index)
# Out:
# 66224

# %%
def textToDataframe(text):
    text = text.replace('$', ',')
    dataframe = pd.read_json(text, orient='records')
    return(dataframe)

def extractEyetrackingData(data):
    data_eyetracking = pd.DataFrame(columns=['x', 'y', 't'])
    data["et_data"] = data['et_data'].apply(str)

    et_indices = data.loc[
        (pd.notna(data['et_data'])) & 
        ~(data['et_data'].isin(['"', '[]', 'nan'])), 
        :].index
    index_max = et_indices.max()
    
    for i in tqdm(et_indices):
        
        df = textToDataframe(data.loc[i, 'et_data'])        

        df["t_task"] = (df.loc[:, "t"] - df.loc[0, "t"])
        df['run_id'] = data.loc[i, 'run_id']
        df['trial_index'] = data.loc[i, 'trial_index']

        data_eyetracking = data_eyetracking.append(pd.DataFrame(data=df), ignore_index=True)
    return(data_eyetracking)

data_et = extractEyetrackingData(data_raw.loc[data_raw['run_id'].isin(data_trial['run_id'].unique()), :])
# Out:
# <ipython-input-19-7fd80c6febd3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["et_data"] = data['et_data'].apply(str)
# Reading Index 17 | 0.0%
# Reading Index 19 | 0.0%
# Reading Index 21 | 0.0%
# Reading Index 23 | 0.0%
# Reading Index 25 | 0.0%
# Reading Index 27 | 0.0%
# Reading Index 29 | 0.0%
# Reading Index 31 | 0.0%
# Reading Index 33 | 0.0%
# Reading Index 35 | 0.0%
# Reading Index 37 | 0.0%
# Reading Index 39 | 0.0%
# Reading Index 41 | 0.0%
# Reading Index 43 | 0.0%
# Reading Index 45 | 0.0%
# Reading Index 47 | 0.0%
# Reading Index 49 | 0.0%
# Reading Index 51 | 0.0%
# Reading Index 53 | 0.0%
# Reading Index 55 | 0.0%
# Reading Index 57 | 0.0%
# Reading Index 59 | 0.0%
# Reading Index 61 | 0.0%
# Reading Index 63 | 0.0%
# Reading Index 65 | 0.0%
# Reading Index 67 | 0.1%
# Reading Index 69 | 0.1%
# Reading Index 71 | 0.1%
# Reading Index 73 | 0.1%
# Reading Index 75 | 0.1%
# Reading Index 77 | 0.1%
# Reading Index 79 | 0.1%
# Reading Index 81 | 0.1%
# Reading Index 83 | 0.1%
# Reading Index 85 | 0.1%
# Reading Index 87 | 0.1%
# Reading Index 89 | 0.1%
# Reading Index 91 | 0.1%
# Reading Index 93 | 0.1%
# Reading Index 104 | 0.1%
# Reading Index 105 | 0.1%
# Reading Index 107 | 0.1%
# Reading Index 108 | 0.1%
# Reading Index 110 | 0.1%
# Reading Index 111 | 0.1%
# Reading Index 113 | 0.1%
# Reading Index 114 | 0.1%
# Reading Index 116 | 0.1%
# Reading Index 117 | 0.1%
# Reading Index 119 | 0.1%
# Reading Index 120 | 0.1%
# Reading Index 122 | 0.1%
# Reading Index 123 | 0.1%
# Reading Index 125 | 0.1%
# Reading Index 126 | 0.1%
# Reading Index 128 | 0.1%
# Reading Index 129 | 0.1%
# Reading Index 143 | 0.1%
# Reading Index 144 | 0.1%
# Reading Index 146 | 0.1%
# Reading Index 147 | 0.1%
# Reading Index 149 | 0.1%
# Reading Index 150 | 0.1%
# Reading Index 152 | 0.1%
# Reading Index 153 | 0.1%
# Reading Index 155 | 0.1%
# Reading Index 156 | 0.1%
# Reading Index 158 | 0.1%
# Reading Index 159 | 0.1%
# Reading Index 161 | 0.1%
# Reading Index 162 | 0.1%
# Reading Index 164 | 0.1%
# Reading Index 165 | 0.1%
# Reading Index 167 | 0.1%
# Reading Index 168 | 0.1%
# Reading Index 170 | 0.1%
# Reading Index 171 | 0.1%
# Reading Index 173 | 0.1%
# Reading Index 174 | 0.1%
# Reading Index 132280 | 99.9%
# Reading Index 132282 | 99.9%
# Reading Index 132283 | 99.9%
# Reading Index 132285 | 99.9%
# Reading Index 132286 | 99.9%
# Reading Index 132288 | 99.9%
# Reading Index 132289 | 100.0%
# Reading Index 132291 | 100.0%
# Reading Index 132292 | 100.0%
# Reading Index 132294 | 100.0%
# Reading Index 132295 | 100.0%
# Reading Index 132297 | 100.0%
# Reading Index 132298 | 100.0%
# Reading Index 132300 | 100.0%
# Reading Index 132301 | 100.0%
# Reading Index 132303 | 100.0%
# Reading Index 132304 | 100.0%
# Reading Index 132306 | 100.0%
# Reading Index 132307 | 100.0%
# Reading Index 132309 | 100.0%
# Reading Index 132310 | 100.0%
# Reading Index 132312 | 100.0%
# Reading Index 132313 | 100.0%
# Reading Index 132315 | 100.0%
# Reading Index 132316 | 100.0%
# Reading Index 132318 | 100.0%
# Reading Index 132319 | 100.0%
# Reading Index 132321 | 100.0%
# Reading Index 132322 | 100.0%
# Reading Index 132324 | 100.0%
# Reading Index 132325 | 100.0%
# Reading Index 132327 | 100.0%
# Reading Index 132328 | 100.0%
# Reading Index 132330 | 100.0%
# Reading Index 132331 | 100.0%
# Reading Index 132333 | 100.0%
# Reading Index 132334 | 100.0%
# Reading Index 132336 | 100.0%
# Reading Index 132337 | 100.0%
# Reading Index 132339 | 100.0%
# Reading Index 132340 | 100.0%
# Reading Index 132342 | 100.0%
# Reading Index 132343 | 100.0%
# Reading Index 132345 | 100.0%
# Reading Index 132346 | 100.0%
# Reading Index 132348 | 100.0%
# Reading Index 132349 | 100.0%
# Reading Index 132351 | 100.0%
# Reading Index 132352 | 100.0%
# Reading Index 132354 | 100.0%
# Reading Index 132355 | 100.0%

# %%
data_et = convertToNumeric(data_et, ['x', 'y', 't', 't_task'])

# %%
data_et.groupby(['run_id', 'trial_index'])['x', 'y'].count()
# Out:
# <ipython-input-21-5a412f0f98d6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_et.groupby(['run_id', 'trial_index'])['x', 'y'].count()
#                      x   y
# run_id trial_index
# 1.0    18.0          6   6
#        20.0         11  11
#        22.0         11  11
#        24.0         11  11
#        26.0         10  10
# ...                 ..  ..
# 462.0  518.0        44  44
#        520.0        13  13
#        522.0        44  44
#        524.0        13  13
#        526.0        45  45
#
# [66224 rows x 2 columns]

# %% [markdown]
# # data_subject

# %%
df1 = data_raw.loc[
    :, 
    [
        'run_id',
        'age', 'browliner', 'browser', 'browser_version', 'degree', 'device',
        'ethnic', 'eyeliner', 'eyeshadow', 'gender', 'glasses', 'keptHead',
        'masquara', 'optionalNote', 'platform', 'platform_version', 'sight',
        'triedChin', 'user_agent', 'vertPosition', 'webcam_fps',
        'webcam_height', 'webcam_label', 'webcam_width', 'chosenAmount',
        'chosenDelay'
    ]
].drop_duplicates()
    
df2 = data_trial.loc[
    : ,
    [
        'chinFirst', 'choiceTask_amountLeftFirst', 'run_id', 'prolificID'
    ]
].drop_duplicates()
    
data_subject = df1.merge(df2, on='run_id', how='left') \
    .rename(columns={'age': 'birthyear'})

# %% [markdown]
# ## survey data

# %%
data_subject = data_subject \
    .merge(
        surveyData,
        on='run_id', 
        how='left'
)

# %% [markdown]
# # Var recorded_at

# %%
def add_completed_date(data, data_trial):
    output = []

    for subject in tqdm(data_trial['run_id'].unique()):
        thisSubject = data_trial.loc[data_trial['run_id'] == subject] \
            .reset_index(drop=True)
        date_time_obj = datetime.datetime.strptime(
            thisSubject.loc[0, 'recorded_at'], '%Y-%m-%d %H:%M:%S')

        output.append([thisSubject.loc[0, 'run_id'], date_time_obj.date()])

    output = pd.DataFrame(output, columns=['run_id', 'recorded_date'])

    if 'recorded_date' in data.columns: data = data.drop(columns=['date'])
    data = data.merge(output, on='run_id', how='left')
    return data

data_subject = add_completed_date(data_subject, data_trial)
data_subject['recorded_date']
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 259/259 [00:00<00:00, 613.58it/s]
# 0      2021-01-17
# 1      2021-01-19
# 2             NaN
# 3             NaN
# 4      2021-01-18
#           ...
# 297    2021-01-19
# 298    2021-01-19
# 299    2021-01-19
# 300    2021-01-19
# 301           NaN
# Name: recorded_date, Length: 302, dtype: object

# %% [markdown]
# ## Add prolific data

# %%
data_prolific_int = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/prolific/prolific_export_int.csv') \
    .rename(columns={'participant_id': 'prolificID'}) 

data_prolific_us = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/prolific/prolific_export_us.csv') \
    .rename(columns={'participant_id': 'prolificID'}) \

data_prolific = data_prolific_int \
    .append(data_prolific_us)
print(len(
    data_prolific.loc[data_prolific['status']=='APPROVED', :]))
print(len(data_subject.prolificID.unique()))
# Out:
# 250
# 259

# %%
data_subject = data_subject.merge(data_prolific, on='prolificID', how='left')
data_subject['status'] = data_subject['status'].fillna('NOTPROLIFIC')
data_subject.loc[:, ['run_id', 'prolificID']]
# Out:
#     run_id                prolificID
# 0        1  5fccc8ac636416a4288a9f3d
# 1      103  600063f2943eab0acc812ed8
# 2      106                       NaN
# 3      108                       NaN
# 4       11  5c5684ef9d244c0001b29f1e
# ..     ...                       ...
# 297     94  5ecfc227f036c902457fc44c
# 298     96  5eb9940830ab6c098bd1943d
# 299     97  5f68fe5be5cc370c0a0911de
# 300     98  5f779405dacc842fc44bc767
# 301     99                       NaN
#
# [302 rows x 2 columns]

# %% [markdown]
# # data_prolific
# For participant management

# %%
temp = data_subject.rename(columns={
    'chosenAmount': 'bonus_USD',
    'chosenDelay': 'bonus_delay'
    }
)

data_prolific = data_prolific.merge(
    temp.loc[:, 
        np.append(['prolificID'], 
        temp.columns.difference(data_prolific.columns))], 
    on='prolificID', 
    how='left')

# %% [markdown]
# # Export data

# %%
if not os.path.exists('./data_jupyter'):
    os.mkdir('./data_jupyter')

#data_et.to_csv("data_jupyter/data_et.csv", index=False, header=True)
data_trial.to_csv("data_jupyter/data_trial.csv", index=False, header=True)
data_subject.to_csv("data_jupyter/data_subject_raw.csv", index=False, header=True)
data_prolific.to_csv("data_jupyter/data_prolific.csv", index=False, header=True)

# %% [markdown]
# # Feedback

# %%
print('Success! Script ran through')
# Out:
# Success! Script ran through
