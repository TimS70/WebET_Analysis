# %%
import datetime
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import sys
from datetime import timedelta  

if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO
    
from IPython.display import HTML
def View(df):
    css = """<style>
    table { border-collapse: collapse; border: 3px solid #eee; }
    table tr th:first-child { background-color: #eeeeee; color: #333; font-weight: bold }
    table thead th { background-color: #eee; color: #000; }
    tr, th, td { border: 1px solid #ccc; border-width: 1px 0 0 1px; border-collapse: collapse;
    padding: 3px; font-family: monospace; font-size: 10px }</style>
    """
    s  = '<script type="text/Javascript">'
    s += 'var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
    s += 'win.document.body.innerHTML = \'' + (df.to_html() + css).replace("\n",'\\') + '\';'
    s += '</script>'
    return(HTML(s+css))    
    
print("Current Working directory " , os.getcwd())
# Out:
# Current Working directory  C:\Users\User\GitHub\WebET_Analysis

# %%
data_et = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/data_jupyter/data_et.csv')
data_et_fix = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/data_jupyter/data_et_fix.csv')
data_et_choice = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/data_jupyter/data_et_choice.csv')

data_trial = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/data_jupyter/data_trial.csv')
data_trial_fix = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/data_jupyter/data_trial_fix.csv')
data_trial_choice = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/data_jupyter/data_trial_choice.csv')

data_subject = pd.read_csv(r'C:/Users/User/GitHub/WebET_Analysis/data_jupyter/data_subject.csv') \
    .rename(columns=
            {
                'chosenAmount': 'bonus_pay',
                'chosenDelay': 'bonus_delay'
            }
           )    

overview = pd.DataFrame(
    [
        [len(data_et)],
        [len(data_et_fix)],
        [len(data_et_choice)],
        [len(data_trial)],
        [len(data_trial_fix)],
        [len(data_trial_choice)],
        [len(data_subject)]
    ], 
    columns=['length'],
    index=['data_et', 'data_et_fix', 'data_et_choice', 
           'data_trial', 'data_trial_fix', 'data_trial_choice', 
           'data_subject'])
print(overview)
# Out:
#                    length
# data_et            618566
# data_et_fix         57762
# data_et_choice     148345
# data_trial          30362
# data_trial_fix        918
# data_trial_choice    3655
# data_subject           84

# %% [markdown]
# # Approve subjects

# %%
if 'trial_length' in data_subject.columns: 
    print('trial_length already added!')
else:
    output = []
    for subject in data_trial['run_id'].unique():
        prolificID = data_trial.loc[data_trial['run_id']==subject, 'prolificID'].unique()[0]
        trial_length = len(data_trial.loc[data_trial['run_id']==subject, 'trial_index'].unique())
        output.append([subject, prolificID, trial_length])
    output = pd.DataFrame(output,
                 columns=['run_id', 'prolificID', 'trial_length']
                )

    data_subject = data_subject.merge(output, on=['run_id', 'prolificID'], how='left')

# %%
data_et = data_et.merge(
    data_trial.loc[:, ['run_id', 'chinFirst', 'trial_index', 'trial_type', 'task_nr']], 
    on=['run_id', 'trial_index'], 
    how='left'
)

# %%
output = []
for subject in data_et['run_id'].unique():
    m_x_fix = data_et.loc[
        (data_et['run_id']==subject) &
        (data_et['trial_type']=='eyetracking-fix-object') &
        ~((data_et['chinFirst']==1) & (data_et['task_nr']==2) |
          (data_et['chinFirst']==0) & (data_et['task_nr']==3) 
         ), 
        'x'
    ].mean()
    m_x_choice = data_et.loc[
        (data_et['run_id']==subject) &
        (data_et['trial_type']=='eyetracking-choice'), 
        'x'
    ].mean()

    m_y_fix = data_et.loc[
        (data_et['run_id']==subject) &
        (data_et['trial_type']=='eyetracking-fix-object') &
        ~((data_et['chinFirst']==1) & (data_et['task_nr']==2) |
          (data_et['chinFirst']==0) & (data_et['task_nr']==3) 
         ), 
        'y'
    ].mean()
    m_y_choice = data_et.loc[
        (data_et['run_id']==subject) &
        (data_et['trial_type']=='eyetracking-choice'), 
        'y'
    ].mean()

    m_count_fix = data_et.loc[
        (data_et['run_id']==subject) &
        (data_et['trial_type']=='eyetracking-fix-object') &
        ~((data_et['chinFirst']==1) & (data_et['task_nr']==2) |
          (data_et['chinFirst']==0) & (data_et['task_nr']==3) 
         ), 
        'x'
    ].count()

    m_count_choice = data_et.loc[
        (data_et['run_id']==subject) &
        (data_et['trial_type']=='eyetracking-choice'), 
        'x'
    ].count()
    
    m_choseTop = data_trial_choice.loc[data_trial_choice['run_id']==subject,
                                       'choseTop'].mean()

    output.append([subject, m_x_fix, m_y_fix, m_x_choice, m_y_choice, 
                   m_count_fix, m_count_choice, 
                   m_choseTop])

output = pd.DataFrame(output, 
                      columns=['run_id', 'm_x_fix', 'm_y_fix', 'm_x_choice', 'm_y_choice', 
                               'm_count_fix', 'm_count_choice',
                               'm_choseTop'])
output

data_subject = data_subject.merge(output, on='run_id', how='left')

# %% [markdown]
# ## These subjects await review

# %%
data_subject.loc[data_subject['status']=='AWAITING REVIEW', 
                 ['run_id', 'prolificID', 'trial_length',
                 'm_x_fix', 'm_y_fix', 'm_x_choice', 'm_y_choice', 'm_count_fix', 'm_count_choice',
                 'm_choseTop']
                ].sort_values(by='prolificID')
# Out:
# Empty DataFrame
# Columns: [run_id, prolificID, trial_length, m_x_fix, m_y_fix, m_x_choice, m_y_choice, m_count_fix, m_count_choice, m_choseTop]
# Index: []

# %%
if 'choice_rt' in data_subject.columns:
    print('choice_rt already added!')
else: 
    grouped = data_trial.loc[data_trial['trial_type']=='eyetracking-choice', :] \
        .groupby(['prolificID'])['trial_duration_exact'].mean() \
        .reset_index() \
        .rename(columns={'trial_duration_exact': 'choice_rt'})
    data_subject = data_subject.merge(grouped, on='prolificID', how='left')

data_subject.loc[
    data_subject['status']=='AWAITING REVIEW', 
    ['run_id', 'prolificID', 'webcam_fps', 'choice_rt', 'bonus_pay', 'bonus_delay']
] \
    .sort_values(by='run_id')
# Out:
# Empty DataFrame
# Columns: [run_id, prolificID, webcam_fps, choice_rt, bonus_pay, bonus_delay]
# Index: []

# %% [markdown]
# # Basic payment

# %%
data_pay = data_subject.loc[data_subject['status']=='APPROVED', 
                            [
                                'run_id', 'prolificID', 
                                'age',  'Country of Birth', 'Current Country of Residence', 'First Language',
                                'Nationality', 'Sex',
                                'status', 'reviewed_at_datetime', 'Country of Birth', 'entered_code',
                                'session_id', 'started_datetime', 'completed_date_time', 'time_taken',
                                'bonus_pay', 'bonus_delay'
                            ]
                           ]

data_pay['basic_pay'] = 2.25
data_pay.loc[:, ['bonus_pay', 'bonus_delay']]
# Out:
#    bonus_pay bonus_delay
# 1       $4.5    180 days
# 4       $3.5       Today
# 5        NaN         NaN
# 8       $4.5     90 days
# 9       $4.5      7 days
# 10        $5     30 days
# 11        $4       Today
# 12      $3.5       Today
# 14      $4.5      7 days
# 15        $3       Today
# 16      $4.5     90 days
# 17      $2.5       Today
# 18        $3       Today
# 19      $4.5     90 days
# 20   50 cent       Today
# 21        $3       Today
# 22        $4    Tomorrow
# 23      $4.5     30 days
# 24      $4.5     30 days
# 25        $5    Tomorrow
# 26        $4     30 days
# 27      $4.5     30 days
# 28      $4.5       Today
# 29        $4      7 days
# 31      $4.5     30 days
# 33      $4.5       Today
# 34        $5     15 days
# 35        $4     15 days
# 36        $5     15 days
# 37       NaN         NaN
# 38        $4     15 days
# 39        $5     30 days
# 40        $2       Today
# 41        $4     30 days
# 42        $5      7 days
# 44        $5     30 days
# 45        $5     30 days
# 46        $4      7 days
# 47      $3.5       Today
# 49      $4.5    Tomorrow
# 51       NaN         NaN
# 52        $3       Today
# 53      $2.5       Today
# 54      $4.5     15 days
# 55        $2       Today
# 56        $4     15 days
# 57      $4.5     90 days
# 58      $4.5     30 days
# 59        $4     30 days

# %% [markdown]
# # Bonus payment

# %% [markdown]
# Reformat payments

# %%
def choice_options_to_numeric(data, varName): 
    data[varName] = data[varName].astype(str)
    data.loc[: , [varName]] = \
        data.loc[:, [varName]] \
            .replace(['Today', 'Tomorrow', '7 days', 
                      '15 days', '30 days', '90 days', 
                      '180 days'], 
                     [0, 1, 7, 15, 30, 90, 180]) \
            .replace({'\$':''}, regex = True) \
            .replace('50 cent', 0.5) \
            .astype(float)
    return data

for var in ['bonus_pay', 'bonus_delay']:
    data_pay = choice_options_to_numeric(data_pay, var)

# %%
data_pay[['run_id', 'prolificID', 'bonus_pay', 'bonus_delay']]
# Out:
#     run_id                prolificID  bonus_pay  bonus_delay
# 0      103  600063f2943eab0acc812ed8        4.5        180.0
# 1       11  5c5684ef9d244c0001b29f1e        3.5          0.0
# 2       12  5b8969006651ea000118e42e        5.0          1.0
# 3      126  5c0e4e3d87e876000151cfec        4.5         90.0
# 4      128  5f01a0893963d02ea1d65d12        4.5          7.0
# 5       13  5b4e65de09f5af0001080f45        5.0         30.0
# 6      130  5fea19869bf07d97b4a87ae8        4.0          0.0
# 7      131  5e53a7b4d9a7ea3a2b062da0        3.5          0.0
# 8       19  5f860a189bc695131f22ec9c        4.5          7.0
# 9       24  5f77a902fc647a327b77004a        3.0          0.0
# 10      25  5cf0ccf488abf10019fb775d        4.5         90.0
# 11      28  5f561a95aa1c4ea13672f138        2.5          0.0
# 12      30  5eeaa0ffaa6af11cf32ce057        3.0          0.0
# 13      32  5ea94df3a879f002f3e9a812        4.5         90.0
# 14      36  5f8472685956c40c720d0936        0.5          0.0
# 15      37  5f0cb319d29147695796a208        3.0          0.0
# 16      38  5f1e9db721e4f101783fe21c        4.0          1.0
# 17       4  5f96fc2552ce3f040af63bbc        4.5         30.0
# 18      41  5f881c7d29650a26096e77a3        4.5         30.0
# 19      42  5fcbb3066829ff1a601fe080        5.0          1.0
# 20      43  5f946436ae32a127565d9405        4.0         30.0
# 21      45  5f1aac6058391f01dacbf619        4.5         30.0
# 22      47  5f5793d85411a8251740e602        4.5          0.0
# 23      48  5fa1192cf99e161a5cfad1cd        4.0          7.0
# 24       5  5ea3f75481a44e39aa318256        4.5         30.0
# 25      56  5e79d99f6873570009367716        4.5          0.0
# 26      58  5de5157820c5aa09b7a53b89        5.0         15.0
# 27      59  5fe6fb05b9b609059e4613e0        4.0         15.0
# 28       6  5f4e08aafb74230a29cb4ef0        5.0         15.0
# 29      61  5fb2af792942a58ffe303948        5.0          1.0
# 30      63  5fc6bcbc6da34d0f8dd78a3a        4.0         15.0
# 31      66  5bd170999afb5b00015ba3b1        5.0         30.0
# 32      67  5cfb9f6f288ca80001169952        2.0          0.0
# 33       7  5fd41bf508717e1833d8aed7        4.0         30.0
# 34      70  5d430fdf871f1700017b2a81        5.0          7.0
# 35      74  5aa7b522b5e2110001c74775        5.0         30.0
# 36      75  5d00bb3b51669b000136a986        5.0         30.0
# 37      80  5fa69c24315bfb2d0a37c685        4.0          7.0
# 38      81  5c6cb4163023800001e71898        3.5          0.0
# 39      85  5e2db0f07dc16b3a611516bd        4.5          1.0
# 40       9  5fea6632bf9ae4a79153efdf        5.0          1.0
# 41      90  5cf67b30c5cf0e00010c00fc        3.0          0.0
# 42      91  5f256074297aac1d8ef7382d        2.5          0.0
# 43      92  5f91b067130f8504520cdd6f        4.5         15.0
# 44      93  5f4756db83588013e9e31bfc        2.0          0.0
# 45      94  5ecfc227f036c902457fc44c        4.0         15.0
# 46      96  5eb9940830ab6c098bd1943d        4.5         90.0
# 47      97  5f68fe5be5cc370c0a0911de        4.5         30.0
# 48      98  5f779405dacc842fc44bc767        4.0         30.0

# %% [markdown]
# ## Replace empty values with the best bonus reward

# %%
# For two subjects, the bonus payment was not recorded
data_pay.loc[
    data_pay['prolificID'].isin(
        ['5fea6632bf9ae4a79153efdf', 
         '5b8969006651ea000118e42e', 
         '5fb2af792942a58ffe303948', 
        ]
    ), ['bonus_pay', 'bonus_delay']] = [5, 1]

data_pay.loc[data_pay[['bonus_pay', 'bonus_delay']].isnull().any(axis=1), :]
# Out:
# Empty DataFrame
# Columns: [run_id, prolificID, age, Country of Birth, Current Country of Residence, First Language, Nationality, Sex, status, reviewed_at_datetime, Country of Birth, entered_code, session_id, started_datetime, completed_date_time, time_taken, bonus_pay, bonus_delay, basic_pay, date, completed_date, reward_pound]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## What bonus is due today?

# %%
def add_completed_date(data, data_trial):
    output = []

    for subject in data_trial['run_id'].unique():
        thisSubject = data_trial.loc[data_trial['run_id']==subject] \
            .reset_index(drop=True)
        date_time_obj = datetime.datetime.strptime(
            thisSubject.loc[0, 'recorded_at'], '%Y-%m-%d %H:%M:%S')

        output.append([thisSubject.loc[0, 'run_id'], date_time_obj.date()])
        
    output = pd.DataFrame(output, columns=['run_id', 'date']) 
    
    if 'date' in data.columns: data = data.drop(columns=['date'])
    data = data.merge(output, on='run_id', how='left')
    return data

data_pay = add_completed_date(data_pay, data_trial)
    
data_pay['completed_date']=data_pay.apply(
    lambda x: datetime.datetime.strptime(
        x['completed_date_time'], '%Y-%m-%d %H:%M:%S.%f') \
            .date(),
    axis=1)
data_pay['bonus_pay'].unique()
# Out:
# array([4.5, 3.5, 5. , 4. , 3. , 2.5, 0.5, 2. ])

# %%
data_pay['reward_pound'] = data_pay['bonus_pay'] * 0.75

# %%
data_pay['due_on'] = data_pay['completed_date'] +  data_pay['bonus_delay'].map(datetime.timedelta) 

data_pay.loc[:, 
               [
                   'prolificID', 'run_id',
                   'Nationality', 'Sex',  
                   'completed_date', 'bonus_pay', 'bonus_delay', 
                   'reward_pound'
               ]
              ]. sort_values(by='completed_date')
# Out:
#                   prolificID  run_id     Nationality     Sex completed_date  \
# 24  5ea3f75481a44e39aa318256       5          Israel    Male     2021-01-18
# 28  5f4e08aafb74230a29cb4ef0       6          Poland    Male     2021-01-18
# 6   5fea19869bf07d97b4a87ae8     130           Spain    Male     2021-01-19
# 4   5f01a0893963d02ea1d65d12     128          Greece    Male     2021-01-19
# 3   5c0e4e3d87e876000151cfec     126          Poland  Female     2021-01-19
# 32  5cfb9f6f288ca80001169952      67          Poland    Male     2021-01-19
# 48  5f779405dacc842fc44bc767      98        Portugal    Male     2021-01-19
#
#     bonus_pay  bonus_delay  reward_pound
# 24        4.5         30.0         3.375
# 28        5.0         15.0         3.750
# 40        5.0          1.0         3.750
# 20        4.0         30.0         3.000
# 19        5.0          1.0         3.750
# 18        4.5         30.0         3.375
# 17        4.5         30.0         3.375
# 16        4.0          1.0         3.000
# 14        0.5          0.0         0.375
# 13        4.5         90.0         3.375
# 12        3.0          0.0         2.250
# 15        3.0          0.0         2.250
# 10        4.5         90.0         3.375
# 1         3.5          0.0         2.625
# 2         5.0          1.0         3.750
# 11        2.5          0.0         1.875
# 5         5.0         30.0         3.750
# 33        4.0         30.0         3.000
# 8         4.5          7.0         3.375
# 9         3.0          0.0         2.250
# 43        4.5         15.0         3.375
# 45        4.0         15.0         3.000
# 46        4.5         90.0         3.375
# 34        5.0          7.0         3.750
# 41        3.0          0.0         2.250
# 39        4.5          1.0         3.375
# 38        3.5          0.0         2.625
# 37        4.0          7.0         3.000
# 36        5.0         30.0         3.750
# 35        5.0         30.0         3.750
# 44        2.0          0.0         1.500
# 42        2.5          0.0         1.875
# 0         4.5        180.0         3.375
# 31        5.0         30.0         3.750
# 30        4.0         15.0         3.000
# 29        5.0          1.0         3.750
# 27        4.0         15.0         3.000
# 26        5.0         15.0         3.750
# 25        4.5          0.0         3.375
# 47        4.5         30.0         3.375
# 23        4.0          7.0         3.000
# 22        4.5          0.0         3.375
# 21        4.5         30.0         3.375
# 7         3.5          0.0         2.625
# 6         4.0          0.0         3.000
# 4         4.5          7.0         3.375
# 3         4.5         90.0         3.375
# 32        2.0          0.0         1.500
# 48        4.0         30.0         3.000

# %%
bonus_due_today = data_pay.loc[data_pay['due_on']==datetime.datetime.now().date(), :]
bonus_due_today['reward_pound'] = bonus_due_today['reward_pound'].round(2)
bonus_due_today
# Out:
# <ipython-input-32-e0c5874ff982>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bonus_due_today['reward_pound'] = bonus_due_today['reward_pound'].round(2)
#     run_id                prolificID   age Country of Birth  \
# 4      128  5f01a0893963d02ea1d65d12  26.0          Germany
# 23      48  5fa1192cf99e161a5cfad1cd  18.0           Poland
# 34      70  5d430fdf871f1700017b2a81  49.0            Spain
# 37      80  5fa69c24315bfb2d0a37c685  20.0           Poland
#
#    Current Country of Residence First Language Nationality   Sex    status  \
# 4                        Greece          Greek      Greece  Male  APPROVED
# 23                       Poland   DATA EXPIRED      Poland  Male  APPROVED
# 34                        Spain        Catalan       Spain  Male  APPROVED
# 37                       Poland   DATA EXPIRED      Poland  Male  APPROVED
#
#           reviewed_at_datetime  ...            started_datetime  \
# 4   2021-01-19 12:36:47.163000  ...  2021-01-19 10:23:21.887000
# 23  2021-01-19 11:00:41.549000  ...  2021-01-19 09:09:18.617000
# 34  2021-01-19 10:41:24.134000  ...  2021-01-19 09:10:03.087000
# 37  2021-01-19 11:00:49.360000  ...  2021-01-19 09:09:12.814000
#
#            completed_date_time time_taken bonus_pay bonus_delay  basic_pay  \
# 4   2021-01-19 11:01:30.874000   2288.987       4.5         7.0       2.25
# 23  2021-01-19 09:44:13.747000   2095.130       4.0         7.0       2.25
# 34  2021-01-19 10:41:23.434000   5480.347       5.0         7.0       2.25
# 37  2021-01-19 09:44:37.014000   2124.200       4.0         7.0       2.25
#
#     completed_date  reward_pound        date      due_on
# 4       2021-01-19          3.38  2021-01-19  2021-01-26
# 23      2021-01-19          3.00  2021-01-19  2021-01-26
# 34      2021-01-19          3.75  2021-01-19  2021-01-26
# 37      2021-01-19          3.00  2021-01-19  2021-01-26
#
# [4 rows x 23 columns]

# %%
bonus_due_today.loc[: , ['prolificID', 'reward_pound']] \
    .to_csv('C:/Users/User/Google Drive/Masterarbeit/Acquise/bonusToday.csv', 
            index=False, 
            header=False
           )
print(bonus_due_today['due_on'].unique())
# Out:
# [datetime.date(2021, 1, 26)]

# %% [markdown]
# # Total costs

# %%
data_pay['basic_cost'] = data_pay['basic_pay'] * 1.4
data_pay['total_cost'] = (data_pay['basic_pay'] + data_pay['bonus_pay']) * 1.4
print('Basic Costs: ' + str(sum(data_pay['basic_cost'])))
print('Total Costs: ' + str(sum(data_pay['total_cost'])))
data_pay
# Out:
# Basic Costs: 154.35000000000014
# Total Costs: 432.9499999999997
#     run_id                prolificID   age Country of Birth  \
# 0      103  600063f2943eab0acc812ed8  19.0            Italy
# 1       11  5c5684ef9d244c0001b29f1e  29.0        Hong Kong
# 2       12  5b8969006651ea000118e42e  22.0            Italy
# 3      126  5c0e4e3d87e876000151cfec  29.0           Poland
# 4      128  5f01a0893963d02ea1d65d12  26.0          Germany
# 5       13  5b4e65de09f5af0001080f45  29.0           Poland
# 6      130  5fea19869bf07d97b4a87ae8  19.0            Spain
# 7      131  5e53a7b4d9a7ea3a2b062da0  40.0   United Kingdom
# 8       19  5f860a189bc695131f22ec9c  20.0           Poland
# 9       24  5f77a902fc647a327b77004a  27.0   United Kingdom
# 10      25  5cf0ccf488abf10019fb775d  18.0      New Zealand
# 11      28  5f561a95aa1c4ea13672f138  37.0            Italy
# 12      30  5eeaa0ffaa6af11cf32ce057  20.0           Poland
# 13      32  5ea94df3a879f002f3e9a812  23.0           Poland
# 14      36  5f8472685956c40c720d0936  21.0            Italy
# 15      37  5f0cb319d29147695796a208  36.0            Italy
# 16      38  5f1e9db721e4f101783fe21c  19.0           Poland
# 17       4  5f96fc2552ce3f040af63bbc  23.0            Spain
# 18      41  5f881c7d29650a26096e77a3  28.0   United Kingdom
# 19      42  5fcbb3066829ff1a601fe080  34.0   United Kingdom
# 20      43  5f946436ae32a127565d9405  24.0         Portugal
# 21      45  5f1aac6058391f01dacbf619  32.0           Poland
# 22      47  5f5793d85411a8251740e602  19.0           Poland
# 23      48  5fa1192cf99e161a5cfad1cd  18.0           Poland
# 24       5  5ea3f75481a44e39aa318256  26.0           Israel
# 25      56  5e79d99f6873570009367716  26.0   United Kingdom
# 26      58  5de5157820c5aa09b7a53b89  21.0           Greece
# 27      59  5fe6fb05b9b609059e4613e0  23.0           Mexico
# 28       6  5f4e08aafb74230a29cb4ef0  19.0           Poland
# 29      61  5fb2af792942a58ffe303948  28.0          Germany
# 30      63  5fc6bcbc6da34d0f8dd78a3a  18.0           Poland
# 31      66  5bd170999afb5b00015ba3b1  51.0         Portugal
# 32      67  5cfb9f6f288ca80001169952  30.0           Poland
# 33       7  5fd41bf508717e1833d8aed7  26.0           Mexico
# 34      70  5d430fdf871f1700017b2a81  49.0            Spain
# 35      74  5aa7b522b5e2110001c74775  37.0   United Kingdom
# 36      75  5d00bb3b51669b000136a986  38.0           Poland
# 37      80  5fa69c24315bfb2d0a37c685  20.0           Poland
# 38      81  5c6cb4163023800001e71898  26.0           Greece
# 39      85  5e2db0f07dc16b3a611516bd  38.0   United Kingdom
# 40       9  5fea6632bf9ae4a79153efdf  44.0           Serbia
# 41      90  5cf67b30c5cf0e00010c00fc  38.0            Spain
# 42      91  5f256074297aac1d8ef7382d  23.0          Hungary
# 43      92  5f91b067130f8504520cdd6f  25.0            Italy
# 44      93  5f4756db83588013e9e31bfc  30.0     South Africa
# 45      94  5ecfc227f036c902457fc44c  22.0   United Kingdom
# 46      96  5eb9940830ab6c098bd1943d  25.0           Israel
# 47      97  5f68fe5be5cc370c0a0911de  32.0   United Kingdom
# 48      98  5f779405dacc842fc44bc767  24.0         Portugal
#
#    Current Country of Residence First Language     Nationality     Sex  \
# 0                         Italy            NaN           Italy    Male
# 1                 United States        Chinese   United States    Male
# 2                         Italy        Italian           Italy  Female
# 3                        Poland         Polish          Poland  Female
# 4                        Greece          Greek          Greece    Male
# 5                        Poland         Polish          Poland    Male
# 6                         Spain            NaN           Spain    Male
# 7                United Kingdom        English  United Kingdom  Female
# 8                        Poland   DATA EXPIRED          Poland    Male
# 9                United Kingdom   DATA EXPIRED  United Kingdom  Female
# 10               United Kingdom            Twi  United Kingdom  Female
# 11               United Kingdom   DATA EXPIRED           Italy    Male
# 12                       Poland         Polish          Poland    Male
# 13                       Poland         Polish          Poland  Female
# 14                        Italy   DATA EXPIRED           Italy    Male
# 15               United Kingdom        Italian           Italy    Male
# 16                       Poland         Polish          Poland    Male
# 17                        Spain   DATA EXPIRED           Spain    Male
# 18               United Kingdom   DATA EXPIRED  United Kingdom    Male
# 19               United Kingdom   DATA EXPIRED  United Kingdom  Female
# 20                     Portugal            NaN        Portugal    Male
# 21                       Poland         Polish          Poland    Male
# 22                       Poland   DATA EXPIRED          Poland    Male
# 23                       Poland   DATA EXPIRED          Poland    Male
# 24                       Israel        Russian          Israel    Male
# 25               United Kingdom        English  United Kingdom  Female
# 26                       Greece          Greek          Greece    Male
# 27                       Mexico   DATA EXPIRED          Mexico    Male
# 28                       Poland   DATA EXPIRED          Poland    Male
# 29                      Germany            NaN         Germany  Female
# 30                       Poland   DATA EXPIRED          Poland    Male
# 31                     Portugal     Portuguese        Portugal  Female
# 32                       Poland         Polish          Poland    Male
# 33                          NaN            NaN          Mexico    Male
# 34                        Spain        Catalan           Spain    Male
# 35               United Kingdom        English  United Kingdom  Female
# 36                       Poland         Polish          Poland    Male
# 37                       Poland   DATA EXPIRED          Poland    Male
# 26        15.0      2.25     2021-01-19         3.750  2021-01-19  2021-02-03
# 27        15.0      2.25     2021-01-19         3.000  2021-01-19  2021-02-03
# 28        15.0      2.25     2021-01-18         3.750  2021-01-18  2021-02-02
# 29         1.0      2.25     2021-01-19         3.750  2021-01-19  2021-01-20
# 30        15.0      2.25     2021-01-19         3.000  2021-01-19  2021-02-03
# 31        30.0      2.25     2021-01-19         3.750  2021-01-19  2021-02-18
# 32         0.0      2.25     2021-01-19         1.500  2021-01-19  2021-01-19
# 33        30.0      2.25     2021-01-18         3.000  2021-01-18  2021-02-17
# 34         7.0      2.25     2021-01-19         3.750  2021-01-19  2021-01-26
# 35        30.0      2.25     2021-01-19         3.750  2021-01-19  2021-02-18
# 36        30.0      2.25     2021-01-19         3.750  2021-01-19  2021-02-18
# 37         7.0      2.25     2021-01-19         3.000  2021-01-19  2021-01-26
# 38         0.0      2.25     2021-01-19         2.625  2021-01-19  2021-01-19
# 39         1.0      2.25     2021-01-19         3.375  2021-01-19  2021-01-20
# 40         1.0      2.25     2021-01-18         3.750  2021-01-18  2021-01-19
# 41         0.0      2.25     2021-01-19         2.250  2021-01-19  2021-01-19
# 42         0.0      2.25     2021-01-19         1.875  2021-01-19  2021-01-19
# 43        15.0      2.25     2021-01-19         3.375  2021-01-19  2021-02-03
# 44         0.0      2.25     2021-01-19         1.500  2021-01-19  2021-01-19
# 45        15.0      2.25     2021-01-19         3.000  2021-01-19  2021-02-03
# 46        90.0      2.25     2021-01-19         3.375  2021-01-19  2021-04-19
# 47        30.0      2.25     2021-01-19         3.375  2021-01-19  2021-02-18
# 48        30.0      2.25     2021-01-19         3.000  2021-01-19  2021-02-18
#
#     basic_cost total_cost
# 0         3.15       9.45
# 1         3.15       8.05
# 2         3.15      10.15
# 3         3.15       9.45
# 4         3.15       9.45
# 5         3.15      10.15
# 6         3.15       8.75
# 7         3.15       8.05
# 8         3.15       9.45
# 9         3.15       7.35
# 10        3.15       9.45
# 11        3.15       6.65
# 12        3.15       7.35
# 13        3.15       9.45
# 14        3.15       3.85
# 15        3.15       7.35
# 16        3.15       8.75
# 17        3.15       9.45
# 18        3.15       9.45
# 19        3.15      10.15
# 20        3.15       8.75
# 21        3.15       9.45
# 22        3.15       9.45
# 23        3.15       8.75
# 24        3.15       9.45
# 25        3.15       9.45
# 26        3.15      10.15
# 27        3.15       8.75
# 28        3.15      10.15
# 29        3.15      10.15
# 30        3.15       8.75
# 31        3.15      10.15
# 32        3.15       5.95
# 33        3.15       8.75
# 34        3.15      10.15
# 35        3.15      10.15
# 36        3.15      10.15
# 37        3.15       8.75
# 38        3.15       8.05
# 39        3.15       9.45
# 40        3.15      10.15
# 41        3.15       7.35
# 42        3.15       6.65
# 43        3.15       9.45
# 44        3.15       5.95
# 45        3.15       8.75
# 46        3.15       9.45
# 47        3.15       9.45
# 48        3.15       8.75
#
# [49 rows x 25 columns]

# %% [markdown]
# # Export modified prolific data

# %%
data_pay.to_csv('C:/Users/User/Google Drive/Masterarbeit/Acquise/data_pay.csv', index=False, header=True)

# %% [markdown]
# # Feedback

# %%
print('Success! Script ran through.')
# Out:
# Success! Script ran through.
